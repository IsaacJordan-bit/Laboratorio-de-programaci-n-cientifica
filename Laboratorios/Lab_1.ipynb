# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Ignacio Meza D.
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Diego Cortez

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Jordan Perez
# - Nombre de alumno 2: Benjamín Farías

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/IsaacJordan-bit/Laboratorio-de-programaci-n-cientifica

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2 pts)

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
#  - 1: Git es un distributed version control system (DVCS), un tipo de control de versión donde cada desarrollador posee una copia del código.
#  - 2:
#     - Git es un DVCS mientras que GitHub es servicio de almacenamiento basado en web.
#     - Git se opera desde linea de comandos y GitHub de una interfaz gráfica.
#     - Git es un software y crea un repositorio local. GitHub es un espacio donde subir copias del repositorio.
#
#  - 3: Es una llave de 40 caracteres que puede apuntar un blob, commit o árbol. Ejemplo: 27938aa5e861f739d69ef6385c51ac5725891700
#
#  - 4: Los principales elementos que componen la estructura de datos son:  "blob",  "Commit" y "Tree".
#
#  -5:
#     - Para crear un nuevo repositorio, se utiliza el comando "git init"
#     - Para ver los cambios que se han hecho en el proyecto se utiliza el comando "git status", mientras que para ver el contenido modificado de los archivos se utiliza el comando "git diff" (Puede emplearse el comando "git diff [archivo]" para precisar la muestra). Además, el comando "git diff --cached" muestra los cambios que se incluirán en el historial si se hace commit, y si no se quiere ver todo el contenido de los cambios del comando diff, puede emplearse el comando "git diff --stat" que muestra un sumario de los cambios.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. Cada miembro del equipo trabaja en la misma copia del código fuente usando `Git`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# - 6: F. Es posible que existan colisiones en el trabajo realizado dentro de distintas ramas. Estas ocurren
# cuando 2 personas trabajan en las mismas líneas de código y luego intentan unir sus cambios.
# Estas colisiones se denominan conflictos y comunmente deben resolverse a mano y luego subir los cambios.
#
# - 7: F. El comando “git clone” se utiliza para empezar a trabajar, ya que agrega el repositorio remoto al area de trabajo, mientras que el comando “git pull” descarga una actualización del estado del repositorio remoto al repositorio local y a los archivos (osea combina un fetch y un merge).
# - 8: F. Comunmente cada miembro trabaja en una brach, una copia del código hasta cierta versión comun.
# - 9: V.  puede usarse tanto "git revert" como "git reset" para deshacer cualquier cambio no deseado.
# - 10: F. "git commit" guarda los cambios en el repositorio local pero no en el remoto.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (2 pts)

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Crear y modificar un archivo `readme.md` con la información que ustedes deseen compartir.
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba).
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/Anzarts/Anzarts/tree/main
#
# <code>Link Presentacion 2:</code> https://github.com/IsaacJordan-bit/Presentaci-n_personal

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)

# %% [markdown]
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (incluya también los comandos en `Git` ocupados):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>git clone https://github.com/MDS7202/lab1.git</code>
#
# ---

# %% [markdown]
# 2. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también de cada componente que lo conforma. (0.25 pts)

# %% [markdown]
# Según el readme se trata de un proyecto para emular sonidos de animales. La rama main además del readme el repositorio contiene otros 2 archivos, animales.py y main.py. El primero define una función que entrega sonidos de animales y el segundo define un sistema interactivo donde el usuario solicita un animal y el programa le entrega su sonido.
#
# El repositorio tiene 2 ramas más, fix-ifs y new_features. En fix_ifs la función definida en animales.py de la rama main está en main.py y cambia los `if` que siguen al primero por `elif`. new_features es igual a main.

# %% [markdown]
# 3. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# `cd lab1`
#
# `git log --all --graph --decorate`
#
# Los mensajes de los últimos commits son:
#
# - "fix ifs"
# - "se separa el proyecto en modulos"
# - "se agrega funcion"
# - "primer commit"
#
# No son especialmente informativos los commits realizados

# %% [markdown]
# 4. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>git blame main.py</code>
#
# <code>git blame animales.py</code>
#
# El error es que se tiene una sucesión de ifs que, como print no detiene la ejecución, siempre que el argumento no es "fox" da error. La persona que cometió en error es mezosky.

# %% [markdown]
# 5. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# `git show c8b1a62d7299552b0654f930d695b33109214111`
#
# `git show 362fe21ee44f53ee944cee4ba484600308f83d78`
#
# `git show 25543a3baf77292baf849726784ca005473acab1`
#
# El primero agrega la función animales a main.py, el segundo crea un archivo animales.py donde define la función animales y el último, en main.py, cambia el segundo y tercer if de animales por elif.

# %% [markdown]
# 6. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>git merge origin/fix-ifs main</code>
#
# Da el siguiente mensage:
#
# "CONFLICT (content): merge conflict in main.py
# Automatic merge failed; fix conflicts and then commit the result."

# %% [markdown]
# No se puede realizar merge porque existe conflicto entre las ramas, es decir, existe un archivo que fue nodificado en main y fix-ifs luego separar las ramas. En este caso luego de crear la rama fix-ifs, en main se separó el proyecto en módulos, de modo que en ambas ramas se modificó main.py en paralelo.

# %% [markdown]
# 7. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.5 pts)

# %% [markdown]
# <code>git merge --abort</code>
#
# <code>git brach animales_fixed</code>
#
# <code>git checkout animales_fixed</code>
#
# <code>git add animales.py</code>
#
# <code>git commit -m "fix ifs in animales.py"</code>
#
# <code>git merge animales_fixed main</code>

# %% [markdown]
# La solución sería crear una nueva rama, que sería idéntica a la última versión de main, y ahí arreglar los if en la función animales de animales.py, luego al hacer merge no debería haber conflicto.

# %% [markdown]
# Código corregido:

# %%
def animales(input):
    
    '''
    Como hace el animalito?
    '''
    
    if input.lower() == 'gato':
        print('miau')
    elif input.lower() == 'perro':
        print('guau')
    elif input.lower() == 'fox':
        print('https://www.youtube.com/watch?v=jofNR_WkoCE')
    else:
        raise ValueError('animal no reconocido :(')

# %% [markdown]
# Se modificaron las líneas 9 y 11 de animales.py

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300>
